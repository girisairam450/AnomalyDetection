# %%
from tensorflow import keras
from sklearn.preprocessing import StandardScaler
import numpy as np
import tensorflow as tf
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed

# %% [markdown]
# ## Load the Data
#
# We will use the [Alphabet Inc.(Google)](https://finance.yahoo.com/quote/GOOG/history?p=GOOG) dataset. The time period used is `('2004-08-19', '2020-12-24')`.

# %%
df = pd.read_csv('Stocks\GOOG.csv')

# %% [markdown]
# ## Quick look at data

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2019-04-22  61.799500  62.454498  61.415501  62.442001  62.442001  16146000
# 1  2019-04-23  62.534500  63.450001  62.319000  63.227501  63.227501  26398000
# 2  2019-04-24  63.206001  63.400501  62.750000  62.799999  62.799999  20376000
# 3  2019-04-25  63.238499  63.370399  62.601501  63.172501  63.172501  22146000
# 4  2019-04-26  63.450001  63.653500  63.015999  63.609001  63.609001  24828000

# %%
# Extract "Date" and "Close" feature colums from the dataframe. 
df = df[['Date', 'Close', 'Volume']]

# %%
# Concise summary of a DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1183 entries, 0 to 1182
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1183 non-null   object
#  1   Close   1183 non-null   float64
#  2   Volume  1183 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 27.9+ KB

# %% [markdown]
# **Data Time Period**

# %%
df['Date'].min(), df['Date'].max()
# Out:
# ('2019-04-22', '2023-12-29')

# %% [markdown]
# ## Visualize the data

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df['Date'], y=df['Close'], name='Close price'))
fig.update_layout(showlegend=True, title='Google Stock Price 2019-2024')
fig.show()
fig2 = go.Figure()
fig2.add_trace(go.Scatter(x=df['Date'], y=df['Volume'], name='Volume'))
fig2.update_layout(showlegend=True, title='Google Stock Price 2019-2024')
fig2.show()

# %% [markdown]
# ## Data Preprocessing

# %%
df[['Close','Volume']].head()
# Out:
#        Close    Volume
# 0  62.442001  16146000
# 1  63.227501  26398000
# 2  62.799999  20376000
# 3  63.172501  22146000
# 4  63.609001  24828000

# %%
len(df)
# Out:
# 1183

# %%
scaler = StandardScaler()
scaler = scaler.fit(df[['Close','Volume']])
scaled_train = scaler.transform(df[['Close','Volume']])
#train_df = pd.DataFrame(scaled_train,columns = ['Close','Volume'])

# %%
scaled_train[0:5]
# Out:
# array([[-1.3374812 , -1.00458351],
#        [-1.31047676, -0.21576535],
#        [-1.32517371, -0.67911523],
#        [-1.31236759, -0.54292638],
#        [-1.2973613 , -0.33656564]])

# %%
def generate_sequences(data, window_size):
  _l = len(data) 
  Xs = []
  Ys = []
  for i in range(0, (_l - window_size)):
    Xs.append(data[i:i+window_size,:])
    Ys.append(data[i+window_size,:])
  return np.array(Xs), np.array(Ys)

# %%
TIME_STEPS = 1
X_train, Y_train= generate_sequences(scaled_train, TIME_STEPS)
print("Training input shape: ", X_train.shape)
print("Training output shape: ", Y_train.shape)
# Out:
# Training input shape:  (1182, 1, 2)
# Training input shape:  (1182, 2)

# %%
X_train[0]
# Out:
# array([[-1.3374812 , -1.00458351]])

# %%
Y_train[0]
# Out:
# array([-1.31047676, -0.21576535])

# %%
# set seed to regenerate same sequence of random numbers. 
np.random.seed(21)
tf.random.set_seed(21)

# %% [markdown]
# ## Build a model

# %%
model = Sequential()
model.add(LSTM(128, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(LSTM(64, activation='relu'))
model.add(Dropout(rate=0.1))
model.add(Dense(X_train.shape[2]))
#model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 1, 128)            67072
#
#  lstm_19 (LSTM)              (None, 64)                49408
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 116,610
# Trainable params: 116,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
history = model.fit(X_train,
                    Y_train,
                    validation_split=0.2,
                    epochs=100,
                    batch_size=32,
                    #callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)],
                    shuffle=False)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 14s 75ms/step - loss: 1.0522 - val_loss: 0.7609
# Epoch 2/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.9988 - val_loss: 0.7246
# Epoch 3/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.9010 - val_loss: 0.6423
# Epoch 4/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.7054 - val_loss: 0.4804
# Epoch 5/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.5071 - val_loss: 0.2985
# Epoch 6/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.4137 - val_loss: 0.2662
# Epoch 7/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3737 - val_loss: 0.2594
# Epoch 8/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3569 - val_loss: 0.2575
# Epoch 9/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3486 - val_loss: 0.2549
# Epoch 10/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3536 - val_loss: 0.2549
# Epoch 11/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3498 - val_loss: 0.2550
# Epoch 12/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3435 - val_loss: 0.2547
# Epoch 13/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3411 - val_loss: 0.2555
# Epoch 14/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3431 - val_loss: 0.2539
# Epoch 15/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3372 - val_loss: 0.2554
# Epoch 16/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3446 - val_loss: 0.2556
# Epoch 17/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3409 - val_loss: 0.2585
# Epoch 18/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3389 - val_loss: 0.2582
# Epoch 19/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3422 - val_loss: 0.2625
# Epoch 20/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3380 - val_loss: 0.2595
# Epoch 21/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3406 - val_loss: 0.2729
# Epoch 22/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3439 - val_loss: 0.2609
# Epoch 23/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3415 - val_loss: 0.2792
# Epoch 24/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3541 - val_loss: 0.2561
# Epoch 25/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3404 - val_loss: 0.2709
# Epoch 26/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3519 - val_loss: 0.2564
# Epoch 27/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3357 - val_loss: 0.2644
# Epoch 28/100
# 30/30 [==============================] - 1s 28ms/step - loss: 0.3481 - val_loss: 0.2562
# Epoch 29/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3378 - val_loss: 0.2604
# Epoch 30/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.3415 - val_loss: 0.2572
# Epoch 31/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3352 - val_loss: 0.2590
# Epoch 32/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.3414 - val_loss: 0.2570
# Epoch 33/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3291 - val_loss: 0.2592
# Epoch 34/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3332 - val_loss: 0.2571
# Epoch 35/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3311 - val_loss: 0.2588
# Epoch 36/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3396 - val_loss: 0.2571
# Epoch 37/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3320 - val_loss: 0.2587
# Epoch 38/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3303 - val_loss: 0.2566
# Epoch 39/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3308 - val_loss: 0.2584
# Epoch 40/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3301 - val_loss: 0.2574
# Epoch 41/100
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3360 - val_loss: 0.2611
# Epoch 42/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3357 - val_loss: 0.2576
# Epoch 43/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3280 - val_loss: 0.2634
# Epoch 44/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3369 - val_loss: 0.2574
# Epoch 45/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3316 - val_loss: 0.2699
# Epoch 46/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3296 - val_loss: 0.2589
# Epoch 47/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3300 - val_loss: 0.2714
# Epoch 48/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3398 - val_loss: 0.2596
# Epoch 49/100
# 30/30 [==============================] - 1s 21ms/step - loss: 0.3298 - val_loss: 0.2787
# Epoch 50/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3403 - val_loss: 0.2596
# Epoch 51/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3298 - val_loss: 0.2792
# Epoch 52/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3396 - val_loss: 0.2594
# Epoch 53/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3368 - val_loss: 0.2757
# Epoch 54/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3409 - val_loss: 0.2599
# Epoch 55/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3331 - val_loss: 0.2725
# Epoch 56/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3383 - val_loss: 0.2589
# Epoch 57/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3309 - val_loss: 0.2701
# Epoch 58/100
# 30/30 [==============================] - 0s 17ms/step - loss: 0.3347 - val_loss: 0.2590
# Epoch 59/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.3248 - val_loss: 0.2649
# Epoch 60/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3258 - val_loss: 0.2595
# Epoch 61/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3303 - val_loss: 0.2651
# Epoch 62/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3316 - val_loss: 0.2596
# Epoch 63/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3264 - val_loss: 0.2629
# Epoch 64/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3330 - val_loss: 0.2595
# Epoch 65/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3250 - val_loss: 0.2628
# Epoch 66/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3280 - val_loss: 0.2608
# Epoch 67/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3219 - val_loss: 0.2612
# Epoch 68/100
# 30/30 [==============================] - 0s 17ms/step - loss: 0.3258 - val_loss: 0.2628
# Epoch 69/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3255 - val_loss: 0.2596
# Epoch 70/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3310 - val_loss: 0.2671
# Epoch 71/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3279 - val_loss: 0.2595
# Epoch 72/100
# 30/30 [==============================] - 0s 17ms/step - loss: 0.3344 - val_loss: 0.2734
# Epoch 73/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.3299 - val_loss: 0.2608
# Epoch 74/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3295 - val_loss: 0.2754
# Epoch 75/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3346 - val_loss: 0.2627
# Epoch 76/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3339 - val_loss: 0.2768
# Epoch 77/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3326 - val_loss: 0.2644
# Epoch 78/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3273 - val_loss: 0.2810
# Epoch 79/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.3401 - val_loss: 0.2638
# Epoch 80/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3342 - val_loss: 0.2772
# Epoch 81/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3378 - val_loss: 0.2639
# Epoch 82/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3334 - val_loss: 0.2740
# Epoch 83/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3324 - val_loss: 0.2636
# Epoch 84/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.3268 - val_loss: 0.2692
# Epoch 85/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.3286 - val_loss: 0.2633
# Epoch 86/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.3252 - val_loss: 0.2677
# Epoch 87/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.3261 - val_loss: 0.2630
# Epoch 88/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3192 - val_loss: 0.2690
# Epoch 89/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3233 - val_loss: 0.2636
# Epoch 90/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3263 - val_loss: 0.2713
# Epoch 91/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.3252 - val_loss: 0.2629
# Epoch 92/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3279 - val_loss: 0.2720
# Epoch 93/100
# 30/30 [==============================] - 0s 10ms/step - loss: 0.3259 - val_loss: 0.2645
# Epoch 94/100
# 30/30 [==============================] - 0s 13ms/step - loss: 0.3229 - val_loss: 0.2713
# Epoch 95/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.3270 - val_loss: 0.2645
# Epoch 96/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.3227 - val_loss: 0.2679
# Epoch 97/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3238 - val_loss: 0.2644
# Epoch 98/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3247 - val_loss: 0.2682
# Epoch 99/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.3235 - val_loss: 0.2645
# Epoch 100/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.3239 - val_loss: 0.2679

# %% [markdown]
# #### Plot Training - Validation loss

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
model.save('saved_models/lstm_multi_no_window.h5')

# %%
new_df = pd.read_csv('Stocks\Test.csv')
new_df = new_df[['Date','Close','Volume']]
scaled_new_test = scaler.transform(new_df[['Close','Volume']])

X_new, Y_new = generate_sequences(scaled_new_test, TIME_STEPS)
new_test_pred = model.predict(X_new, verbose=1)
# Out:
# 3/3 [==============================] - 1s 9ms/step

# %%
print(scaled_new_test.shape)
print(new_test_pred.shape)
print(X_new.shape)
# Out:
# (76, 2)
# (75, 2)
# (75, 1, 2)

# %%
new_test_pred_seq, _ = generate_sequences(new_test_pred, TIME_STEPS)
print(new_test_pred_seq.shape)
# Out:
# (74, 1, 2)

# %%
import shap
import tensorflow as tf
user_model = tf.keras.models.load_model('saved_models\lstm_multi_no_window.h5')

# %%
explainer = shap.GradientExplainer(user_model, X_new)
shap_values = explainer.shap_values(X_new)
# Out:
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %%
print(shap_values[0].shape) # Close Price
print(shap_values[1].shape) # Volume
print(len(shap_values))
print(X_new.shape)
# Out:
# (75, 1, 2)
# (75, 1, 2)
# 2
# (75, 1, 2)

# %%
[(75, 1, 2), (75, 1, 2)]
[(75, 5, 2), (75, 5, 2)]

# %%
print(shap_values)
# Out:
# [array([[[-0.25416121,  0.0065222 ]],
#
#        [[-0.22796683, -0.00457593]],
#
#        [[-0.32062113, -0.01260762]],
#
#        [[-0.3245708 , -0.02199069]],
#
#        [[-0.25202531, -0.01023592]],
#
#        [[-0.13753034, -0.00119066]],
#
#        [[-0.109788  , -0.01660409]],
#
#        [[-0.11482514, -0.01318085]],
#
#        [[-0.1195955 , -0.03080379]],
#
#        [[-0.10883766, -0.00142078]],
#
#        [[-0.14628518, -0.00917326]],
#
#        [[-0.04842742, -0.00139339]],
#
#        [[ 0.03717251,  0.01747288]],
#
#        [[ 0.02067265,  0.0054775 ]],
#
#        [[ 0.0702204 , -0.02948122]],
#
#        [[ 0.11638496, -0.00204682]],
#
#        [[ 0.2457888 ,  0.00284337]],
#
#        [[ 0.24264652, -0.00120751]],
#
#        [[ 0.29183868,  0.00070513]],
#
#        [[ 0.24586895,  0.01636726]],
#
#        [[-0.16331369,  0.00183199]],
#
#        [[-0.16129121,  0.01555143]],
#
#        [[-0.14186577,  0.01441017]],
#
#        [[-0.05090053,  0.02281768]],
#
#        [[-0.02842236,  0.00780591]],
#
#        [[-0.01042535,  0.00831107]],
#
#        [[ 0.02359654, -0.00667526]],
#
#        [[ 0.15092553,  0.00453629]],
#
#        [[ 0.07815557, -0.01060585]],
#
#        [[-0.01067718, -0.00756462]],
#
#        [[ 0.0321954 , -0.01538068]],
#
#        [[-0.1186998 ,  0.01611789]],
#
#        [[-0.17314407,  0.0092443 ]],
#
#        [[-0.15233436, -0.00712072]],
#
#        [[-0.09014158, -0.01745874]],
#
#        [[-0.03379047,  0.01070214]],
#
#        [[-0.05351071, -0.02639846]],
#
#        [[-0.26021117,  0.0209611 ]],
#
#        [[-0.2478912 ,  0.01492207]],
#
#        [[-0.29230794,  0.01872601]],
#
#        [[-0.24262503,  0.02442413]],
#
#        [[-0.26795018,  0.02047426]],
#
#        [[-0.44402391, -0.02051813]],
#
#        [[-0.4484891 ,  0.02412874]],
#
#        [[-0.46764243,  0.02282412]],
#
#        [[-0.3792392 ,  0.01945408]],
#
#        [[-0.35081899,  0.02117402]],
#
#        [[-0.25332898,  0.01478594]],
#
#        [[-0.24677944, -0.00534754]],
#
#        [[-0.19082125, -0.00107621]],
#
#        [[-0.09820694,  0.02648016]],
#
#        [[-0.16040085,  0.01487019]],
#
#        [[ 0.03449221,  0.01763819]],
#
#        [[ 0.03659427, -0.00830599]],
#
#        [[ 0.12539853, -0.00950224]],
#
#        [[ 0.0876538 ,  0.0015403 ]],
#
#        [[ 0.17719959, -0.00203   ]],
#
#        [[ 0.17513594, -0.02420502]],
#
#        [[ 0.18729614,  0.00064109]],
#
#        [[ 0.17703997, -0.01139571]],
#
#        [[ 0.21697417,  0.00132142]],
#
#        [[ 0.35407257,  0.00810651]],
#
#        [[ 0.38003308, -0.01130565]],
#
#        [[ 0.36568284, -0.01108556]],
#
#        [[ 0.15984254,  0.01108229]],
#
#        [[ 0.26738885, -0.0136573 ]],
#
#        [[ 0.34384686, -0.0095879 ]],
#
#        [[ 0.43173778,  0.00067662]],
#
#        [[ 0.42082718, -0.01320232]],
#
#        [[ 0.54782218, -0.00961907]],
#
#        [[ 0.48446575, -0.01014927]],
#
#        [[ 0.35917407,  0.00063322]],
#
#        [[ 0.34140521, -0.0152904 ]],
#
#        [[ 0.37410104, -0.0133536 ]],
#
#        [[ 0.40702209, -0.0225551 ]]]), array([[[ 3.45530286e-02, -6.44104406e-02]],
#
#        [[ 3.52424607e-02, -1.57562464e-01]],
#
#        [[ 4.09364179e-02, -1.72099456e-01]],
#
#        [[ 4.04298976e-02, -3.25025052e-01]],
#
#        [[ 3.54337171e-02, -2.23183438e-01]],
#
#        [[ 2.46557165e-02, -1.39062017e-01]],
#
#        [[ 2.11635940e-02, -2.92575061e-01]],
#
#        [[ 2.04301570e-02, -2.23259389e-01]],
#
#        [[ 2.26841923e-02, -4.22262967e-01]],
#
#        [[ 2.07527205e-02, -1.05077222e-01]],
#
#        [[ 2.56761629e-02, -2.16989771e-01]],
#
#        [[ 1.20680844e-02, -1.25663102e-01]],
#
#        [[-2.34046820e-04,  2.57275492e-01]],
#
#        [[ 2.74526351e-03, -4.52514505e-03]],
#
#        [[-2.75278813e-03, -4.17230368e-01]],
#
#        [[-1.42470011e-02, -9.54609141e-02]],
#
#        [[-3.82711850e-02, -4.35553566e-02]],
#
#        [[-3.75685468e-02, -1.21829070e-01]],
#
#        [[-4.92174141e-02, -2.94467304e-02]],
#
#        [[-3.25106941e-02,  2.01503679e-01]],
#
#        [[ 1.65580455e-02,  8.85254979e-01]],
#
#        [[ 3.17599513e-02,  1.72093958e-01]],
#
#        [[ 1.47204539e-02,  8.75471413e-01]],
#
#        [[ 1.33386906e-02,  3.45376998e-01]],
#
#        [[ 1.12452852e-02, -3.16814557e-02]],
#
#        [[ 8.02148879e-03, -1.25668300e-02]],
#
#        [[ 4.68449341e-03, -1.88669339e-01]],
#
#        [[-2.10659187e-02, -2.82405186e-02]],
#
#        [[-5.27729234e-03, -2.71150917e-01]],
#
#        [[ 8.43148492e-03, -1.62077725e-01]],
#
#        [[ 1.22809724e-03, -2.85973996e-01]],
#
#        [[ 2.41007451e-02,  2.06062615e-01]],
#
#        [[ 3.25496644e-02,  6.17976440e-03]],
#
#        [[ 2.47988105e-02, -1.68149486e-01]],
#
#        [[ 1.62526257e-02, -3.04505169e-01]],
#
#        [[ 1.20681273e-02,  5.54226264e-02]],
#
#        [[ 1.33435261e-02, -4.03156936e-01]],
#
#        [[ 3.79786342e-02,  5.11236906e-01]],
#
#        [[ 4.30425070e-02,  8.93859267e-02]],
#
#        [[ 4.41766866e-02,  3.90169382e-01]],
#
#        [[ 3.17870006e-02,  6.09546006e-01]],
#
#        [[ 4.36915122e-02,  3.12637836e-01]],
#
#        [[ 3.71862911e-02,  8.80025089e-01]],
#
#        [[ 7.09110275e-02,  3.22560310e-01]],
#
#        [[ 4.09696624e-02,  6.67550266e-02]],
#
#        [[ 5.72306067e-02,  8.71059895e-02]],
#
#        [[ 5.89329004e-02,  2.60343045e-01]],
#
#        [[ 4.11322266e-02,  2.71166731e-02]],
#
#        [[ 3.24638635e-02, -1.23866960e-01]],
#
#        [[ 2.52988711e-02, -1.09409049e-01]],
#
#        [[ 1.49363503e-02,  6.39509916e-01]],
#
#        [[ 1.72533244e-02,  8.30994010e-01]],
#
#        [[ 4.13894420e-03,  1.13060927e+00]],
#
#        [[ 1.45013933e-03, -1.99979559e-01]],
#
#        [[-1.23458682e-02, -2.23633841e-01]],
#
#        [[-6.11561118e-03, -1.21092327e-01]],
#
#        [[-2.53689773e-02, -1.18210562e-01]],
#
#        [[-2.18631197e-02, -3.88702780e-01]],
#
#        [[-2.65365299e-02, -1.13353789e-01]],
#
#        [[-2.16467734e-02, -2.77346194e-01]],
#
#        [[-3.02403923e-02, -7.58345202e-02]],
#
#        [[-5.30653894e-02,  1.11471176e-01]],
#
#        [[-6.55262694e-02, -2.29246274e-01]],
#
#        [[-6.01646751e-02, -2.40639001e-01]],
#
#        [[-2.25442275e-02,  1.49833351e-01]],
#
#        [[-3.76916416e-02, -2.68062621e-01]],
#
#        [[-5.96906506e-02, -2.38896787e-01]],
#
#        [[-7.26779252e-02, -3.82969007e-02]],
#
#        [[-7.57860467e-02, -3.25671643e-01]],
#
#        [[-1.01303466e-01, -2.03303352e-01]],
#
#        [[-9.02529061e-02, -2.56578952e-01]],
#
#        [[-5.72110899e-02, -6.97463006e-02]],
#
#        [[-4.80767116e-02, -3.29570204e-01]],
#
#        [[-6.74342215e-02, -2.80851096e-01]],
#
#        [[-6.24139681e-02, -4.18238550e-01]]])]

# %%
scaled_new_test[TIME_STEPS:].shape
# Out:
# (75, 2)

# %%
last_idx_arr = []
for item in shap_values[0]:
    #print(item[-1])
    last_idx_arr.append(item[-1])
last_idx_arr = np.array(last_idx_arr)
print(last_idx_arr.shape)
# Out:
# (75, 2)

# %%
shap.summary_plot(last_idx_arr, scaled_new_test[TIME_STEPS:])
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.dependence_plot(0, last_idx_arr, scaled_new_test[TIME_STEPS:])

# %%
#shap.plots.beeswarm(explainer)

# %%
shap.bar_plot(last_idx_arr[70])
shap.bar_plot(last_idx_arr[0])

# %%
last_idx_arr2 = []
for item in shap_values[1]:
    #print(item[-1])
    last_idx_arr2.append(item[-1])
last_idx_arr2 = np.array(last_idx_arr2)
print(last_idx_arr2.shape)
# Out:
# (75, 2)

# %%
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.summary_plot(last_idx_arr, scaled_new_test[TIME_STEPS:]) #Close Price
shap.summary_plot(last_idx_arr2, scaled_new_test[TIME_STEPS:]) #Volume
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
pred_dict = {
    'Predicted_Close': new_test_pred[:, 0],
    'Predicted_Volume': new_test_pred[:, 1],
    'Actual_Close': Y_new[:, 0],
    'Actual_Volume': Y_new[:, 1],
}

# %%
pred_df = pd.DataFrame(pred_dict)
pred_df.head()
# Out:
#    Predicted_Close  Predicted_Volume  Actual_Close  Actual_Volume
# 0         1.214679         -0.486855      1.341236      -0.786966
# 1         1.233795         -0.552172      1.261477      -0.842442
# 2         1.149835         -0.588594      1.239131      -1.059428
# 3         1.111297         -0.744742      1.347080      -0.889223
# 4         1.230247         -0.629166      1.416869      -0.740385

# %%
fig, ax = plt.subplots(figsize=(10, 6))
#  highlight the  forecast
highlight_start = int(len(pred_df) * 0.9)  
highlight_end = len(pred_df) - 1  # Adjusted to stay within bounds
# Plot the actual values
plt.plot(pred_df[['Actual_Close', 'Actual_Volume']][:highlight_start], label=['Actual_Close', 'Actual_Volume'])
 
# Plot predicted values with a dashed line
plt.plot(pred_df[['Predicted_Close', 'Predicted_Volume']], label=['Predicted_Close', 'Predicted_Volume'], linestyle='--')
 
# Highlight the forecasted portion with a different color
plt.axvspan(pred_df.index[highlight_start], pred_df.index[highlight_end], facecolor='lightgreen', alpha=0.5, label='Forecast')
 
plt.title('Multivariate Time-Series forecasting using LSTM')
plt.xlabel('Dates')
plt.ylabel('Values')
ax.legend()
plt.show()
